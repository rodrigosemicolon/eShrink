# %% [markdown]
# # Task 1 (Detecting pathological gamblers)
# ### Using word embeddings

# %%
P_FILE = "../posts.csv"
TRAIN_TOKEN="../train_df.csv"
TEST_TOKEN="../test_df.csv"
GENERAL_MODELS="../Models"
ROLLING_WINDOW_SIZE=10
BASELINE_COMP=False
TASK=1
METHOD='mean'
EMBEDDINGS = 'GLOVE_CC'
WORD_EMBEDDINGS = "../../word_embeddings/"
MODEL_PATH =f"{GENERAL_MODELS}/WE/{EMBEDDINGS}_{ROLLING_WINDOW_SIZE}" 
seed=23

# %%
from pathlib import Path
Path(MODEL_PATH).mkdir(parents=True, exist_ok=True)

# %%
import gensim
import fasttext
we = {"FASTTEXT_CC":"crawl-300d-2M-subword.bin","GLOVE_TT":"glove-twitter-200.bin", "GLOVE_CC":"glove_cc_300d.bin"}

# %%
if EMBEDDINGS=='GLOVE_TT':
    embeddings = gensim.models.KeyedVectors.load_word2vec_format(WORD_EMBEDDINGS + "glove-twitter-200.bin", binary=True)
    
elif EMBEDDINGS=='GLOVE_CC':
    embeddings = gensim.models.KeyedVectors.load_word2vec_format(WORD_EMBEDDINGS + "glove_cc_300d.bin", binary=True)

elif EMBEDDINGS=='FASTTEXT_CC':
    embeddings = fasttext.load_model(WORD_EMBEDDINGS + "crawl-300d-2M-subword.bin")

# %% [markdown]
# ### opening resulting dataset with pandas

# %%
import pandas as pd
import numpy as np
import os
np.random.seed(seed)

train_df = pd.read_csv(TRAIN_TOKEN, sep='\t')
test_df = pd.read_csv(TEST_TOKEN, sep='\t')
train_df
# Out:
#        User  Post_Nr                                                Raw  \
# 0      3450        0  sports betting number k in debt, feeling very ...
# 1      3450        1  finally accepted that you cannot win gambling ...
# 2      3450        2  blocking software betfilter has anybody used t...
# 3      3450        3  prone to relapse when in debt? i find that whe...
# 4      3450        4  down to my last number on credit card i am num...
# ...     ...      ...                                                ...
# 97853   162      670                                      you sick fuck
# 97854   162      671                       reeeeeeeeeeeeeeeeeeeeeeeeeee
# 97855   162      672  this is so clearly satire! i really do not wan...
# 97856   162      673          he cannot write a story in number minutes
# 97857   162      674                           pay your respekt people!
#
#                                                  Stemmed  \
# 0      sport bet number k in debt , feel veri depress...
# 1      final accept that you can not win gambl relaps...
# 2      block softwar betfilt has anybodi use this , w...
# 3      prone to relaps when in debt ? i find that whe...
# 4      down to my last number on credit card i am num...
# ...                                                  ...
# 97853                                      you sick fuck
# 97854                       reeeeeeeeeeeeeeeeeeeeeeeeeee
# 97855  this is so clear satir ! i realli do not want ...
# 97856           he can not write a stori in number minut
# 97857                           pay your respekt peopl !
#
#                                               Lemmatized  Label
# 0      sports betting number k in debt , feeling very...      1
# 1      finally accepted that you can not win gambling...      1
# 2      blocking software betfilter has anybody used t...      1
# 3      prone to relapse when in debt ? i find that wh...      1
# 4      down to my last number on credit card i am num...      1
# ...                                                  ...    ...
# 97853                                      you sick fuck      0
# 97854                       reeeeeeeeeeeeeeeeeeeeeeeeeee      0
# 97855  this is so clearly satire ! i really do not wa...      0
# 97856         he can not write a story in number minutes      0
# 97857                          pay your respekt people !      0
#
# [97858 rows x 6 columns]

# %%
def rolling_window(df, window_size,stride, field):
    res_map={}
    for user in df['User'].unique():
        user_df = df[df['User']==user]
        res_map[user]=(user_df['Label'].values[0],{})
        posts = user_df[field].values
        iteration=0
        for i in range(0,len(posts),stride):
            res_map[user][1][iteration]=' '.join((posts[i:i+window_size]))
            iteration+=1
    result_df = pd.DataFrame([(k,k1,v1,v[0]) for k,v in res_map.items() for k1,v1 in v[1].items()], columns = ['User','Window_id','Text','Label'])
    
    return result_df

# %%
train_df = rolling_window(train_df,ROLLING_WINDOW_SIZE,1,'Lemmatized')
test_df = rolling_window(test_df,ROLLING_WINDOW_SIZE,1,'Lemmatized')

train_df
# Out:
#        User  Window_id                                               Text  \
# 0      3450          0  sports betting number k in debt , feeling very...
# 1      3450          1  finally accepted that you can not win gambling...
# 2      3450          2  blocking software betfilter has anybody used t...
# 3      3450          3  prone to relapse when in debt ? i find that wh...
# 4      3450          4  down to my last number on credit card i am num...
# ...     ...        ...                                                ...
# 97853   162        670  you sick fuck reeeeeeeeeeeeeeeeeeeeeeeeeee thi...
# 97854   162        671  reeeeeeeeeeeeeeeeeeeeeeeeeee this is so clearl...
# 97855   162        672  this is so clearly satire ! i really do not wa...
# 97856   162        673  he can not write a story in number minutes pay...
# 97857   162        674                          pay your respekt people !
#
#        Label
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 97853      0
# 97854      0
# 97855      0
# 97856      0
# 97857      0
#
# [97858 rows x 4 columns]

# %%
train_df = pd.concat([train_df,test_df])
train_df = train_df.sample(frac=1, random_state=seed).reset_index(drop=True)

# %%
import pickle
def save_model(model, name):
    with open(f"{MODEL_PATH}/{name}",'wb') as f:
        pickle.dump( model,f)

# %% [markdown]
# ## Model part

# %%
from tqdm import tqdm
import re
import operator

def build_vocab(sentences):
    """
    :param sentences: list of list of words
    :return: dictionary of words and their count
    """
    vocab = {}
    for sentence in tqdm(sentences):
        for word in re.findall(r"\w+|[^\w\s]", sentence, re.UNICODE):            
            try:
                vocab[word] += 1
            except KeyError:
                vocab[word] = 1
    vocab = dict(sorted(vocab.items(), key=operator.itemgetter(1))[::-1])
    return vocab

# %%
vocab_dict = build_vocab(train_df['Text'])
vocab_dict
# Out:
# 100%|██████████| 120181/120181 [00:18<00:00, 6360.24it/s]
# {'.': 2569175,
#  'the': 1436450,
#  'i': 1429780,
#  ',': 1241392,
#  'to': 1145950,
#  'a': 971341,
#  'and': 964002,
#  'number': 795759,
#  'is': 760436,
#  'you': 747516,
#  'it': 691554,
#  'of': 645210,
#  'not': 613042,
#  'in': 543362,
#  'that': 523118,
#  'for': 455940,
#  'have': 395204,
#  'my': 349983,
#  'on': 326974,
#  'this': 317034,
#  'are': 304883,
#  'but': 292858,
#  'do': 290925,
#  'was': 284248,
#  '?': 281535,
#  '!': 265067,
#  'with': 245741,
#  'be': 236984,
#  'can': 228418,
#  'am': 221957,
#  'your': 212399,
#  'if': 206356,
#  'so': 205715,
#  'me': 203830,
#  'just': 201635,
#  'will': 190976,
#  'as': 183993,
#  'they': 182990,
#  'at': 181626,
#  'like': 172142,
#  'what': 163027,
#  'or': 160803,
#  'all': 158486,
#  'would': 153632,
#  'out': 149127,
#  'from': 140373,
#  'get': 138576,
#  'he': 135401,
#  'we': 133144,
#  'there': 132309,
#  'about': 128621,
#  'up': 128574,
#  'one': 125160,
#  'money': 121444,
#  'more': 118994,
#  'time': 117777,
#  'url': 117181,
#  'when': 113499,
#  's': 107261,
#  'how': 103989,
#  'an': 100886,
#  'no': 99491,
#  'had': 96923,
#  'some': 96203,
#  'people': 95809,
#  'good': 93964,
#  'has': 93751,
#  'its': 93504,
#  'think': 92320,
#  'did': 92039,
#  'been': 91926,
#  'day': 91786,
#  'by': 90390,
#  'know': 89735,
#  'now': 89709,
#  'gambling': 88321,
#  'them': 82553,
#  'here': 82255,
#  'because': 76458,
#  'much': 76367,
#  'really': 75422,
#  'only': 74305,
#  'go': 72050,
#  'then': 70154,
#  'back': 69889,
#  'going': 69773,
#  'could': 68737,
#  'even': 66410,
#  'who': 66316,
#  'life': 66200,
#  'also': 65376,
#  'way': 65070,
#  'his': 62658,
#  'want': 62373,
#  'make': 61925,
#  'feel': 60700,
#  'got': 60264,
#  'does': 59917,
#  'than': 59230,
#  'she': 59108,
#  'see': 58716,
#  'any': 57886,
#  'over': 57581,
#  'their': 56859,
#  'too': 56776,
#  'first': 56108,
#  'were': 55589,
#  'years': 55461,
#  'other': 55179,
#  'after': 55005,
#  'still': 53060,
#  'well': 52980,
#  'never': 52734,
#  'her': 52024,
#  'off': 51785,
#  'need': 51302,
#  'into': 51218,
#  'should': 50745,
#  'better': 50470,
#  'which': 50276,
#  'very': 50255,
#  'work': 49955,
#  'right': 49360,
#  'new': 48604,
#  'why': 46567,
#  'most': 46429,
#  'him': 46269,
#  'same': 45785,
#  'take': 45686,
#  'best': 45317,
#  'post': 45256,
#  'being': 44169,
#  'thanks': 44152,
#  'us': 44114,
#  'subreddit': 43779,
#  'something': 43416,
#  'where': 42979,
#  'lot': 41794,
#  'every': 41579,
#  'say': 40793,
#  'great': 40521,
#  'again': 40403,
#  'down': 39667,
#  'keep': 39467,
#  'thing': 39261,
#  'game': 39246,
#  'help': 39156,
#  'things': 39033,
#  'use': 38543,
#  'many': 38463,
#  'before': 38284,
#  'always': 38143,
#  'days': 37934,
#  'year': 36797,
#  'few': 36687,
#  'sure': 35885,
#  'last': 35836,
#  'those': 35478,
#  'low': 35351,
#  'our': 35010,
#  'these': 34560,
#  'stop': 34100,
#  'love': 33478,
#  'made': 33346,
#  'long': 32868,
#  'thank': 32610,
#  'someone': 32293,
#  'look': 32179,
#  'said': 32047,
#  'through': 32041,
#  'quality': 31923,
#  'myself': 31438,
#  'laughing': 31396,
#  'find': 31170,
#  'try': 30702,
#  'please': 30531,
#  'getting': 30208,
#  'read': 30203,
#  'doing': 30034,
#  'around': 29585,
#  'bad': 29572,
#  'while': 28891,
#  'used': 28715,
#  'let': 28698,
#  'today': 28506,
#  'two': 28505,
#  'away': 28115,
#  'lost': 27713,
#  'emoji': 27558,
#  'give': 27534,
#  'put': 26967,
#  'times': 26855,
#  'hard': 26695,
#  'k': 26575,
#  'thought': 26534,
#  'anything': 26494,
#  'actually': 26424,
#  'loud': 26398,
#  'since': 26361,
#  'months': 26247,
#  'yes': 26239,
#  'done': 25778,
#  'maybe': 25563,
#  'problem': 25533,
#  'next': 25362,
#  'big': 25349,
#  'another': 25162,
#  'little': 25150,
#  'gamble': 25071,
#  'man': 24982,
#  'ever': 24644,
#  'without': 24487,
#  'week': 24478,
#  'come': 24334,
#  'play': 24025,
#  'end': 23900,
#  'start': 23890,
#  'point': 23870,
#  'pretty': 23690,
#  'enough': 23637,
#  'everything': 23433,
#  'may': 23392,
#  'yeah': 23363,
#  'though': 23133,
#  'free': 23099,
#  'reason': 23050,
#  'already': 22918,
#  'full': 22776,
#  'once': 22761,
#  'probably': 22758,
#  'win': 22620,
#  'trying': 22576,
#  'smiling': 22526,
#  'hope': 22356,
#  'different': 22325,
#  'having': 22311,
#  'yourself': 22226,
#  'own': 21989,
#  'looking': 21829,
#  'case': 21761,
#  'etc': 21718,
#  'job': 21507,
#  'ago': 21187,
#  'anyone': 21122,
#  'removed': 21067,
#  'everyone': 21042,
#  'nothing': 20871,
#  'went': 20856,
#  'person': 20817,
#  'others': 20793,
#  'world': 20373,
#  'might': 20349,
#  'able': 20211,
#  'kind': 20151,
#  'makes': 20140,
#  'addiction': 20129,
#  'old': 20073,
#  'pay': 19918,
#  'real': 19753,
#  'until': 19682,
#  'nice': 19543,
#  'friends': 19487,
#  'bit': 19447,
#  'live': 19436,
#  'tell': 19274,
#  'friend': 19200,
#  'place': 19181,
#  'posts': 19015,
#  'part': 18926,
#  'high': 18788,
#  'submission': 18730,
#  'd': 18730,
#  'happy': 18579,
#  'both': 18502,
#  'self': 18367,
#  'home': 18364,
#  'fuck': 18344,
#  'found': 18333,
#  'started': 18266,
#  'mean': 18212,
#  'feeling': 18027,
#  'took': 17765,
#  'shit': 17750,
#  'rule': 17622,
#  'megathread': 17560,
#  'family': 17513,
#  'definitely': 17439,
#  'mind': 17368,
#  'hours': 17336,
#  'believe': 17244,
#  'change': 17031,
#  'each': 16952,
#  'stay': 16592,
#  'buy': 16562,
#  'month': 16505,
#  'thinking': 16467,
#  'check': 16389,
#  'else': 16322,
#  'using': 16303,
#  'lose': 16291,
#  'least': 16271,
#  'remember': 16213,
#  'casino': 16154,
#  'such': 16121,
#  'making': 16079,
#  'night': 16025,
#  'less': 15932,
#  'show': 15739,
#  'oh': 15550,
#  'far': 15546,
#  'almost': 15474,
#  'account': 15461,
#  'left': 15260,
#  'worth': 15158,
#  'online': 15120,
#  'sorry': 15029,
#  'luck': 15018,
#  'support': 14785,
#  'working': 14761,
#  'idea': 14758,
#  'understand': 14715,
#  'playing': 14630,
#  'saying': 14565,
#  'seems': 14546,
#  'house': 14519,
#  'under': 14442,
#  'effort': 14395,
#  'weeks': 14359,
#  'wanted': 14329,
#  'experience': 14216,
#  'during': 14129,
#  'guess': 14122,
#  'games': 14121,
#  'stuff': 14033,
#  'ask': 13943,
#  'trump': 13929,
#  'taking': 13923,
#  'ok': 13830,
#  'wish': 13814,
#  'seen': 13722,
#  'x': 13691,
#  'story': 13654,
#  'bet': 13650,
#  'easy': 13500,
#  'meme': 13495,
#  'felt': 13457,
#  'fucking': 13450,
#  'wrong': 13382,
#  'guys': 13362,
#  'following': 13315,
#  'school': 13246,
#  'video': 13227,
#  'gets': 13193,
#  'either': 13173,
#  'debt': 13157,
#  'contact': 13073,
#  'sometimes': 12956,
#  'recovery': 12956,
#  'past': 12939,
#  'yet': 12861,
#  'fun': 12786,
#  'small': 12783,
#  'looks': 12666,
#  'care': 12654,
#  'possible': 12617,
#  'rules': 12582,
#  'tried': 12526,
#  'posted': 12504,
#  'card': 12486,
#  'control': 12473,
#  'worse': 12455,
#  'guy': 12444,
#  'later': 12443,
#  'whole': 12430,
#  'reddit': 12408,
#  'future': 12322,
#  'instead': 12257,
#  'top': 12241,
#  'set': 12231,
#  'amount': 12227,
#  'hit': 12216,
#  'came': 12180,
#  'told': 12039,
#  'open': 11976,
#  'watch': 11947,
#  'god': 11884,
#  'sub': 11884,
#  'couple': 11760,
#  'team': 11753,
#  'sounds': 11743,
#  'run': 11736,
#  'call': 11727,
#  'head': 11681,
#  'opinion': 11641,
#  'talk': 11501,
#  'half': 11435,
#  'true': 11380,
#  'against': 11379,
#  'per': 11377,
#  'agree': 11316,
#  'food': 11284,
#  'literally': 11257,
#  'hate': 11231,
#  'must': 11228,
#  'book': 11220,
#  'quit': 11163,
#  'black': 11130,
#  'completely': 11061,
#  'between': 11033,
#  'matter': 10986,
#  'question': 10979,
#  'questions': 10963,
#  'brain': 10954,
#  'side': 10948,
#  'add': 10885,
#  'eat': 10870,
#  'happen': 10829,
#  'however': 10828,
#  'happened': 10827,
#  'advice': 10825,
#  'second': 10818,
#  'says': 10808,
#  'fact': 10789,
#  'gone': 10784,
#  'coming': 10783,
#  'usually': 10738,
#  'th': 10686,
#  'phone': 10592,
#  'soon': 10548,
#  'goes': 10490,
#  'hear': 10477,
#  'season': 10423,
#  'name': 10380,
#  'move': 10374,
#  'strong': 10336,
#  'finally': 10294,
#  'close': 10194,
#  'enjoy': 10171,
#  'ill': 10136,
#  'losses': 10112,
#  'losing': 10082,
#  'water': 10037,
#  'saw': 10030,
#  'especially': 10025,
#  'bc': 10017,
#  'fine': 9987,
#  'alone': 9976,
#  'mg': 9970,
#  'thefunnytweeter': 9962,
#  'wait': 9943,
#  'car': 9914,
#  'super': 9839,
#  'exactly': 9767,
#  'forward': 9761,
#  'situation': 9727,
#  'wife': 9726,
#  'power': 9704,
#  'comes': 9686,
#  'ass': 9678,
#  'often': 9640,
#  'normal': 9614,
#  'works': 9612,
#  'similar': 9612,
#  'issue': 9609,
#  'moderators': 9580,
#  'reading': 9555,
#  'amazing': 9552,
#  'called': 9505,
#  'hesitate': 9450,
#  'white': 9439,
#  'art': 9399,
#  'information': 9396,
#  'leave': 9396,
#  'course': 9380,
#  'credit': 9371,
#  'unfairly': 9367,
#  'awesome': 9348,
#  'important': 9345,
#  'heard': 9328,
#  'huge': 9316,
#  'sense': 9210,
#  'price': 9207,
#  'honestly': 9190,
#  'together': 9149,
#  'kids': 9128,
#  'kwgt': 9128,
#  'meeting': 9103,
#  'cash': 9076,
#  'ones': 9066,
#  'clean': 9057,
#  'cool': 9047,
#  'face': 9026,
#  'longer': 8998,
#  'chance': 8990,
#  'hey': 8983,
#  'means': 8970,
#  'line': 8927,
#  'allowed': 8908,
#  'plan': 8896,
#  'turn': 8896,
#  'whatever': 8895,
#  'discussion': 8892,
#  'war': 8885,
#  'deal': 8845,
#  'three': 8837,
#  'takes': 8806,
#  'rt': 8746,
#  'seem': 8730,
#  'sleep': 8714,
#  'anymore': 8701,
#  'state': 8692,
#  'rest': 8690,
#  'group': 8684,
#  'thoughts': 8655,
#  'hand': 8637,
#  'talking': 8636,
#  'learn': 8609,
#  'paid': 8569,
#  'due': 8560,
#  'pain': 8557,
#  'damn': 8556,
#  'fight': 8540,
#  'level': 8526,
#  'quite': 8474,
#  'loss': 8468,
#  'city': 8442,
#  'become': 8422,
#  'ga': 8412,
#  'bank': 8408,
#  'issues': 8388,
#  'spend': 8381,
#  'helped': 8378,
#  'daily': 8371,
#  'original': 8369,
#  'needs': 8340,
#  'weight': 8328,
#  'needed': 8260,
#  'glad': 8257,
#  'living': 8237,
#  'crazy': 8233,
#  'watching': 8228,
#  'early': 8185,
#  'system': 8174,
#  'g': 8137,
#  'comment': 8136,
#  'subject': 8077,
#  'bought': 8066,
#  'step': 8018,
#  'basic': 7989,
#  'helps': 7981,
#  'stopped': 7970,
#  'likely': 7967,
#  'gambler': 7946,
#  'worked': 7943,
#  'age': 7930,
#  'mine': 7923,
#  'short': 7880,
#  'anyway': 7847,
#  'knew': 7785,
#  'single': 7775,
#  'list': 7761,
#  'basically': 7746,
#  'won': 7740,
#  'health': 7717,
#  'moment': 7707,
#  'based': 7695,
#  'seeing': 7668,
#  'access': 7638,
#  'feels': 7633,
#  'problems': 7632,
#  'm': 7624,
#  'break': 7621,
#  'minutes': 7620,
#  'order': 7618,
#  'morning': 7600,
#  'parents': 7583,
#  'gave': 7546,
#  'wow': 7546,
#  'save': 7546,
#  'country': 7535,
#  'drink': 7527,
#  'interesting': 7527,
#  'easier': 7485,
#  'meetings': 7469,
#  'negative': 7466,
#  'f': 7455,
#  'share': 7415,
#  'worst': 7406,
#  'taken': 7392,
#  'build': 7376,
#  'cards': 7358,
#  'sober': 7332,
#  'pm': 7311,
#  'answer': 7309,
#  'include': 7295,
#  'clear': 7287,
#  'imagine': 7283,
#  'rather': 7263,
#  'app': 7249,
#  'type': 7228,
#  'starting': 7155,
#  'area': 7140,
#  'non': 7131,
#  'example': 7126,
#  'music': 7124,
#  'cut': 7118,
#  'business': 7104,
#  'sick': 7103,
#  'hell': 7097,
#  'happens': 7068,
#  'website': 7043,
#  'absolutely': 7039,
#  'behind': 7023,
#  'body': 7014,
#  'setup': 7002,
#  'kurt': 7000,
#  'drinking': 6981,
#  'bkex': 6972,
#  'twitter': 6965,
#  'edit': 6965,
#  'covid': 6954,
#  'young': 6943,
#  'light': 6933,
#  'link': 6865,
#  'content': 6848,
#  'sound': 6804,
#  'hour': 6802,
#  'near': 6801,
#  'trading': 6774,
#  'social': 6773,
#  'reaction': 6760,
#  'basis': 6751,
#  'difference': 6718,
#  'bring': 6717,
#  'totally': 6717,
#  'user': 6702,
#  'tomorrow': 6677,
#  'okay': 6676,
#  'higher': 6666,
#  'tv': 6630,
#  'public': 6627,
#  'company': 6612,
#  'main': 6607,
#  'news': 6606,
#  'asked': 6599,
#  'fast': 6593,
#  'room': 6592,
#  'images': 6576,
#  'research': 6562,
#  'market': 6556,
#  'sell': 6550,
#  'played': 6548,
#  'entire': 6545,
#  'giving': 6536,
#  'plus': 6530,
#  'red': 6523,
#  'positive': 6511,
#  'death': 6488,
#  'store': 6480,
#  'extra': 6469,
#  'within': 6466,
#  'eventually': 6444,
#  'e': 6428,
#  'decided': 6427,
#  'stupid': 6398,
#  'eating': 6390,
#  'wishes': 6385,
#  'trust': 6377,
#  'general': 6349,
#  'drive': 6330,
#  'ended': 6312,
#  'casinos': 6287,
#  'removal': 6262,
#  'looked': 6254,
#  'follow': 6249,
#  'front': 6236,
#  'recently': 6225,
#  'players': 6218,
#  'send': 6196,
#  'walk': 6188,
#  'source': 6182,
#  'paying': 6181,
#  'beat': 6180,
#  'thread': 6161,
#  'c': 6161,
#  'pro': 6155,
#  'determined': 6131,
#  'hold': 6116,
#  'value': 6114,
#  'widget': 6112,
#  'sad': 6099,
#  'op': 6086,
#  'kept': 6079,
#  'dark': 6060,
#  'currently': 6052,
#  'although': 6048,
#  'truly': 6047,
#  'favorite': 6045,
#  'realize': 6041,
#  'interested': 6040,
#  'known': 6032,
#  'winning': 6021,
#  'dude': 6017,
#  'continue': 6013,
#  'unless': 6011,
#  'player': 6010,
#  'recommend': 6006,
#  'local': 6000,
#  'screenshot': 5998,
#  'girl': 5997,
#  'son': 5990,
#  't': 5981,
#  'large': 5977,
#  'b': 5977,
#  'compulsive': 5937,
#  'safe': 5936,
#  'available': 5934,
#  'pc': 5923,
#  'listen': 5904,
#  'sort': 5893,
#  'spent': 5890,
#  'character': 5884,
#  'forget': 5863,
#  'ways': 5858,
#  'choice': 5850,
#  'focus': 5846,
#  'memes': 5844,
#  'women': 5835,
#  'yesterday': 5830,
#  'berkeley': 5820,
#  'shot': 5815,
#  'late': 5804,
#  'sharing': 5797,
#  'ahead': 5796,
#  'easily': 5793,
#  'wants': 5777,
#  'outside': 5773,
#  'whenever': 5770,
#  'savings': 5765,
#  'version': 5754,
#  'movie': 5747,
#  'google': 5743,
#  'com': 5728,
#  'star': 5728,
#  'kid': 5721,
#  'space': 5718,
#  'primarily': 5716,
#  'given': 5714,
#  'term': 5709,
#  'dead': 5703,
#  'belong': 5691,
#  'apps': 5688,
#  'pick': 5686,
#  'blaine': 5680,
#  'along': 5679,
#  'offer': 5673,
#  'telling': 5666,
#  'became': 5664,
#  'screenshots': 5660,
#  'knows': 5656,
#  'max': 5645,
#  'shows': 5643,
#  'constructive': 5641,
#  'loved': 5622,
#  'artworks': 5620,
#  'putting': 5618,
#  'mom': 5615,
#  'exists': 5611,
#  'turned': 5602,
#  'comments': 5573,
#  'running': 5559,
#  'several': 5556,
#  'judged': 5550,
#  'violation': 5540,
#  'fire': 5533,
#  'drug': 5531,
#  'cost': 5531,
#  'wins': 5510,
#  'obviously': 5509,
#  'series': 5500,
#  'welcome': 5489,
#  'update': 5486,
#  'alcohol': 5480,
#  'party': 5475,
#  'media': 5470,
#  'certain': 5457,
#  'asking': 5426,
#  'p': 5419,
#  'accept': 5405,
#  'weed': 5403,
#  'videos': 5393,
#  'ready': 5391,
#  'gamblers': 5389,
#  'words': 5388,
#  'appreciate': 5385,
#  'reposts': 5380,
#  'picture': 5375,
#  'simple': 5372,
#  'funny': 5370,
#  'perfect': 5366,
#  'history': 5365,
#  'episode': 5350,
#  'earth': 5345,
#  'hoping': 5345,
#  'serious': 5343,
#  'american': 5339,
#  'consider': 5334,
#  'contributes': 5330,
#  'templates': 5329,
#  'process': 5328,
#  'fall': 5312,
#  'community': 5311,
#  'weekend': 5309,
#  'data': 5309,
#  'unoriginal': 5300,
#  'option': 5295,
#  'points': 5282,
#  'honest': 5280,
#  'submitter': 5270,
#  'write': 5265,
#  'deep': 5247,
#  'betting': 5246,
#  'human': 5243,
#  'straight': 5210,
#  'police': 5187,
#  'gives': 5186,
#  'weird': 5180,
#  'site': 5175,
#  'drugs': 5170,
#  'date': 5170,
#  'major': 5168,
#  'million': 5167,
#  'moving': 5165,
#  'unfortunately': 5163,
#  'figure': 5155,
#  'inside': 5144,
#  'current': 5142,
#  'john': 5141,
#  'total': 5134,
#  'posting': 5129,
#  'lucky': 5126,
#  'deposit': 5124,
#  'woman': 5114,
#  'government': 5100,
#  'above': 5091,
#  'states': 5089,
#  'simply': 5084,
#  'common': 5081,
#  'haha': 5077,
#  'drop': 5073,
#  'bitcoin': 5072,
#  'personally': 5059,
#  'instagram': 5044,
#  'hands': 5032,
#  'college': 5019,
#  'anxiety': 4990,
#  'hi': 4989,
#  'interest': 4977,
#  'knowing': 4976,
#  'youtube': 4969,
#  'relapse': 4960,
#  'learned': 4957,
#  'kill': 4947,
#  'tough': 4943,
#  'pros': 4928,
#  'hopefully': 4923,
#  'lives': 4918,
#  'internet': 4916,
#  'multiple': 4909,
#  'fan': 4902,
#  'details': 4901,
#  'peace': 4898,
#  'sent': 4889,
#  'test': 4886,
#  'stress': 4884,
#  'died': 4883,
#  'dad': 4882,
#  'speed': 4872,
#  'message': 4871,
#  'mental': 4871,
#  'drops': 4866,
#  'eyes': 4857,
#  'damage': 4853,
#  'cons': 4852,
#  'waiting': 4843,
#  'battle': 4838,
#  'prime': 4837,
#  'whether': 4822,
#  'meant': 4806,
#  'miss': 4791,
#  'beautiful': 4780,
#  'program': 4772,
#  'baby': 4769,
#  'difficult': 4754,
#  'sports': 4752,
#  'lower': 4743,
#  'changed': 4738,
#  'versus': 4734,
#  'urges': 4731,
#  'relationship': 4729,
#  'trade': 4721,
#  'form': 4709,
#  'hole': 4701,
#  'stories': 4700,
#  'machine': 4678,
#  'added': 4669,
#  'goal': 4665,
#  'seriously': 4663,
#  'bottom': 4661,
#  'facebook': 4653,
#  'learning': 4643,
#  'word': 4639,
#  'financial': 4636,
#  'special': 4632,
#  'song': 4631,
#  'child': 4624,
#  'class': 4621,
#  'worry': 4620,
#  'explain': 4619,
#  'mostly': 4613,
#  'die': 4613,
#  'effect': 4610,
#  'congratulations': 4604,
#  'disease': 4600,
#  'office': 4600,
#  'hot': 4599,
#  'poor': 4591,
#  'average': 4584,
#  'w': 4583,
#  'pass': 4580,
#  'risk': 4564,
#  'road': 4562,
#  'father': 4552,
#  'buying': 4551,
#  'lead': 4535,
#  'sold': 4532,
#  'rate': 4531,
#  'lots': 4529,
#  'attack': 4522,
#  'decent': 4521,
#  'fix': 4520,
#  'urge': 4509,
#  'congrats': 4505,
#  'act': 4501,
#  'options': 4486,
#  'dollars': 4481,
#  'brother': 4471,
#  'avoid': 4469,
#  'appropriate': 4466,
#  'quickly': 4464,
#  'children': 4460,
#  'men': 4444,
#  'league': 4444,
#  'paper': 4442,
#  'building': 4418,
#  'heart': 4403,
#  'action': 4403,
#  'science': 4393,
#  'terrible': 4391,
#  'choose': 4382,
#  'return': 4381,
#  'bro': 4381,
#  'wonder': 4379,
#  'calories': 4373,
#  'pack': 4369,
#  'helpful': 4365,
#  'reality': 4358,
#  'gambled': 4352,
#  'event': 4349,
#  'view': 4348,
#  'sucks': 4344,
#  'monster': 4340,
#  'air': 4340,
#  'himself': 4339,
#  'except': 4318,
#  'actual': 4313,
#  'four': 4291,
#  'personal': 4285,
#  'across': 4277,
#  'service': 4273,
#  'complete': 4265,
#  'everyday': 4255,
#  'fair': 4252,
#  'wear': 4240,
#  'gacha': 4240,
#  'progress': 4239,
#  'reach': 4234,
#  'clearly': 4233,
#  'page': 4233,
#  'fucked': 4216,
#  'calls': 4201,
#  'chat': 4194,
#  'podcast': 4177,
#  'blue': 4162,
#  'depression': 4157,
#  'middle': 4156,
#  'dog': 4144,
#  'biggest': 4142,
#  'screen': 4137,
#  'saved': 4133,
#  ...}

# %%
import operator

def check_embedding_coverage(token_vocab,embeddings):
    a = {}
    oov = {}
    k = 0
    i = 0
    for word in tqdm(token_vocab):
        try:
            a[word] = embeddings[word]
            k += token_vocab[word]
        except:

            oov[word] = token_vocab[word]
            i += token_vocab[word]
            pass

    print('Found embeddings for {:.2%} of vocab'.format(len(a) / len(token_vocab)))
    print('Found embeddings for  {:.2%} of all text'.format(k / (k + i)))
    sorted_x = sorted(oov.items(), key=operator.itemgetter(1))[::-1]

    return sorted_x

# %%
check_embedding_coverage(vocab_dict, embeddings)
# Out:
# 100%|██████████| 64182/64182 [00:00<00:00, 501250.93it/s]
# Found embeddings for 88.04% of vocab
# Found embeddings for  99.61% of all text
# [('thefunnytweeter', 9962),
#  ('kwgt', 9128),
#  ('bkex', 6972),
#  ('covid', 6954),
#  ('emojiay', 3260),
#  ('faceapp', 2776),
#  ('oaycw', 1980),
#  ('hadimukri', 1970),
#  ('cjqzgo', 1970),
#  ('ryzen', 1286),
#  ('binance', 1025),
#  ('benemon', 730),
#  ('megathreads', 680),
#  ('patreon', 560),
#  ('trulieve', 548),
#  ('chasun', 541),
#  ('continant', 510),
#  ('oneplus', 494),
#  ('mihoyo', 490),
#  ('elastos', 454),
#  ('homescreensetup', 404),
#  ('novalaunchersetup', 404),
#  ('androidcustomization', 404),
#  ('androidsetup', 404),
#  ('kwgtsetup', 404),
#  ('kwgtwidgets', 404),
#  ('androidusers', 404),
#  ('androidui', 404),
#  ('phonesetup', 404),
#  ('novasetup', 404),
#  ('androidapp', 404),
#  ('instatech', 404),
#  ('androidhomescreen', 404),
#  ('klwp', 404),
#  ('doordash', 392),
#  ('emojirivesdk', 380),
#  ('finesta', 370),
#  ('veromos', 370),
#  ('arknights', 370),
#  ('gamban', 360),
#  ('wolfdoggpr', 330),
#  ('vaxxers', 310),
#  ('lushen', 310),
#  ('verad', 310),
#  ('vidacann', 300),
#  ('brexit', 295),
#  ('chromecast', 280),
#  ('theomars', 280),
#  ('redmi', 270),
#  ('woosa', 270),
#  ('tgcc', 270),
#  ('thicc', 266),
#  ('khmun', 250),
#  ('mbappe', 240),
#  ('hraesvelg', 230),
#  ('kahwi', 230),
#  ('razerstreamer', 230),
#  ('whearhouse', 220),
#  ('autowear', 220),
#  ('cdrama', 210),
#  ('webull', 210),
#  ('dispensery', 200),
#  ('mangaluru', 194),
#  ('qanon', 190),
#  ('racuni', 190),
#  ('mikene', 190),
#  ('phospine', 190),
#  ('stonks', 184),
#  ('growhealthy', 180),
#  ('mycrene', 180),
#  ('updoot', 180),
#  ('delphoi', 180),
#  ('airpods', 180),
#  ('dispenseries', 180),
#  ('churyumov', 180),
#  ('combkex', 179),
#  ('onlyfans', 177),
#  ('xans', 170),
#  ('dragapult', 170),
#  ('gaethje', 170),
#  ('echoin', 170),
#  ('curaleaf', 170),
#  ('aceship', 170),
#  ('gamstop', 166),
#  ('uwdmu', 163),
#  ('millarini', 160),
#  ('announcementbkex', 160),
#  ('ublock', 155),
#  ('plandemic', 150),
#  ('mushoku', 150),
#  ('shadowpc', 150),
#  ('iqiyi', 150),
#  ('vaxxer', 150),
#  ('gamblock', 147),
#  ('retsuko', 140),
#  ('prestigeing', 140),
#  ('bhrata', 140),
#  ('hypsm', 140),
#  ('horrorcoaster', 140),
#  ('modmail', 140),
#  ('undertale', 140),
#  ('ovitzes', 140),
#  ('akhamamir', 140),
#  ('halphas', 140),
#  ('pregabs', 132),
#  ('shitpost', 130),
#  ('breida', 130),
#  ('psamathe', 130),
#  ('sigmarus', 130),
#  ('wewil', 130),
#  ('mycbdhaven', 130),
#  ('rfkjr', 130),
#  ('sasrp', 130),
#  ('memerman', 121),
#  ('bitmex', 121),
#  ('surterra', 120),
#  ('antinatalist', 120),
#  ('dragonislander', 120),
#  ('mindigo', 120),
#  ('emojismiling', 120),
#  ('pregab', 120),
#  ('misinfocon', 120),
#  ('katakuri', 120),
#  ('homescreentv', 120),
#  ('ultraboost', 120),
#  ('eventuly', 116),
#  ('keyforge', 110),
#  ('onthisday', 110),
#  ('militao', 110),
#  ('eladriel', 110),
#  ('conehome', 110),
#  ('padoru', 110),
#  ('truclear', 110),
#  ('tenembal', 110),
#  ('pressant', 100),
#  ('vandwelling', 100),
#  ('natalist', 100),
#  ('salamangreat', 100),
#  ('stbxw', 100),
#  ('vechain', 100),
#  ('imnesty', 100),
#  ('rubriks', 100),
#  ('baox', 100),
#  ('ilfonic', 100),
#  ('limeline', 100),
#  ('kurtcedes', 100),
#  ('asiimov', 100),
#  ('fornite', 100),
#  ('psama', 100),
#  ('kmusic', 100),
#  ('inteleon', 100),
#  ('indiehackers', 100),
#  ('growthhackers', 100),
#  ('algorand', 100),
#  ('triggerwarning', 100),
#  ('offerup', 98),
#  ('coronovirus', 90),
#  ('betblocker', 90),
#  ('suecorvette', 90),
#  ('ngannou', 90),
#  ('unfitz', 90),
#  ('zaiross', 90),
#  ('ommu', 90),
#  ('iwtl', 90),
#  ('mihyang', 90),
#  ('simplirabb', 90),
#  ('ctftt', 90),
#  ('greninja', 88),
#  ('brandia', 87),
#  ('devilmon', 85),
#  ('paxful', 80),
#  ('natalists', 80),
#  ('runweight', 80),
#  ('gamblersinrecovery', 80),
#  ('hellea', 80),
#  ('yeonhong', 80),
#  ('binkse', 80),
#  ('athenadark', 80),
#  ('jultan', 80),
#  ('kuiil', 80),
#  ('binske', 80),
#  ('etiz', 80),
#  ('mommajessiec', 80),
#  ('blockchains', 80),
#  ('skulie', 80),
#  ('flashscore', 80),
#  ('sugaland', 80),
#  ('pleasebegneiss', 80),
#  ('procsgiving', 80),
#  ('leanfire', 80),
#  ('yodaling', 80),
#  ('vasubreddit', 80),
#  ('cryptocurrencies', 74),
#  ('ptcgo', 72),
#  ('prerolls', 71),
#  ('fomod', 70),
#  ('blingsly', 70),
#  ('keanureeves', 70),
#  ('skippymcgizzard', 70),
#  ('copymama', 70),
#  ('andlookpretty', 70),
#  ('svnsxty', 70),
#  ('onedrive', 70),
#  ('meizuo', 70),
#  ('budtenders', 70),
#  ('cryptohopper', 70),
#  ('continants', 70),
#  ('yedder', 70),
#  ('scicomm', 70),
#  ('reineckii', 70),
#  ('lingjian', 70),
#  ('synerjug', 70),
#  ('khabibs', 70),
#  ('xcloud', 70),
#  ('artamiel', 70),
#  ('kalank', 70),
#  ('laletta', 70),
#  ('gzel', 70),
#  ('settitlematchmode', 70),
#  ('elsharion', 70),
#  ('dsmiling', 70),
#  ('canpay', 70),
#  ('mahrez', 70),
#  ('vlone', 70),
#  ('nibba', 70),
#  ('ethera', 70),
#  ('demonetisation', 70),
#  ('potiorek', 70),
#  ('wildercopy', 69),
#  ('hishoot', 68),
#  ('vandwellers', 65),
#  ('tendies', 64),
#  ('chiwu', 63),
#  ('esmiling', 61),
#  ('dompen', 60),
#  ('masloff', 60),
#  ('faang', 60),
#  ('ifriti', 60),
#  ('rozenstruik', 60),
#  ('oleink', 60),
#  ('bitconnect', 60),
#  ('animekisa', 60),
#  ('verudora', 60),
#  ('sixfootcandy', 60),
#  ('wearos', 60),
#  ('pointsbet', 60),
#  ('omgsooverit', 60),
#  ('medmen', 60),
#  ('critmilla', 60),
#  ('mematic', 60),
#  ('teshar', 60),
#  ('netflismiling', 60),
#  ('skogul', 60),
#  ('hogwartzy', 60),
#  ('auba', 60),
#  ('ellazee', 60),
#  ('albinoshrek', 60),
#  ('sinemia', 60),
#  ('powesubreddit', 60),
#  ('pungbaek', 60),
#  ('cyrpto', 60),
#  ('cockholster', 60),
#  ('spacewizard', 60),
#  ('grailed', 60),
#  ('yfii', 60),
#  ('covfefe', 60),
#  ('thisonesayz', 60),
#  ('winactive', 60),
#  ('faimon', 60),
#  ('hwadam', 60),
#  ('matpat', 60),
#  ('yooda', 60),
#  ('balloonland', 60),
#  ('artfinity', 60),
#  ('barraskewda', 60),
#  ('pokdex', 60),
#  ('hotstar', 60),
#  ('recoveryroadonline', 60),
#  ('cashapp', 60),
#  ('leadositive', 60),
#  ('leadegative', 60),
#  ('doublicat', 58),
#  ('kucoin', 56),
#  ('darkweb', 55),
#  ('altcoins', 53),
#  ('altcoin', 53),
#  ('ipados', 50),
#  ('imensly', 50),
#  ('philliphobia', 50),
#  ('freesync', 50),
#  ('beeeejesq', 50),
#  ('suppoman', 50),
#  ('iwndwyt', 50),
#  ('gorillanipples', 50),
#  ('impaulmccoy', 50),
#  ('hexanet', 50),
#  ('dokis', 50),
#  ('crockettforreal', 50),
#  ('debrid', 50),
#  ('transmogs', 50),
#  ('devilmons', 50),
#  ('mesmiling', 50),
#  ('springtrap', 50),
#  ('deladova', 50),
#  ('realfunghi', 50),
#  ('muminbits', 50),
#  ('bitwarden', 50),
#  ('kissanime', 50),
#  ('whackamo', 50),
#  ('coppesubreddit', 50),
#  ('iheartjane', 50),
#  ('eisendrache', 50),
#  ('reckt', 50),
#  ('cowspiracy', 50),
#  ('tendie', 50),
#  ('hashplant', 50),
#  ('bosmiling', 50),
#  ('velajuel', 50),
#  ('thispeople', 50),
#  ('ziyech', 50),
#  ('uncleduke', 50),
#  ('ungreatfull', 50),
#  ('futmas', 50),
#  ('fitfreak', 50),
#  ('adamgreattweet', 50),
#  ('picklerudd', 50),
#  ('swartist', 50),
#  ('vtsax', 50),
#  ('theandrewnadeau', 50),
#  ('yapld', 50),
#  ('incineroar', 50),
#  ('futbin', 50),
#  ('dashpass', 50),
#  ('gdlauncher', 50),
#  ('bytedance', 50),
#  ('wamai', 50),
#  ('despaisubreddit', 50),
#  ('mudiji', 50),
#  ('inktober', 50),
#  ('ohpee', 50),
#  ('wedinos', 50),
#  ('apriballs', 50),
#  ('pokesubreddit', 50),
#  ('polkaworld', 50),
#  ('cendes', 50),
#  ('xbosmiling', 50),
#  ('ownesubreddit', 50),
#  ('covidrally', 50),
#  ('draftkings', 50),
#  ('srne', 50),
#  ('substats', 50),
#  ('eugeo', 50),
#  ('thesaurizethis', 50),
#  ('teltik', 50),
#  ('facetiming', 50),
#  ('nmil', 50),
#  ('fatlogic', 50),
#  ('niktos', 50),
#  ('wdym', 50),
#  ('ozzyunc', 50),
#  ('manannn', 50),
#  ('coastfire', 50),
#  ('emojiedce', 50),
#  ('icasha', 50),
#  ('zcash', 50),
#  ('libnyi', 50),
#  ('bittrex', 50),
#  ('abrinovi', 50),
#  ('keagen', 49),
#  ('ddlc', 48),
#  ('youser', 48),
#  ('bettesubreddit', 45),
#  ('mushys', 44),
#  ('cannabiotix', 42),
#  ('powercreep', 40),
#  ('ubesubreddit', 40),
#  ('emilies', 40),
#  ('vermintide', 40),
#  ('frostbear', 40),
#  ('ksalols', 40),
#  ('presentsmore', 40),
#  ('elviswithout', 40),
#  ('entourageto', 40),
#  ('vertcoin', 40),
#  ('scorestreak', 40),
#  ('swachh', 40),
#  ('dlore', 40),
#  ('funnybison', 40),
#  ('diclazepam', 40),
#  ('fallschirmjger', 40),
#  ('naabeeh', 40),
#  ('kamasi', 40),
#  ('saquon', 40),
#  ('kabunky', 40),
#  ('computesubreddit', 40),
#  ('vvix', 40),
#  ('yourselff', 40),
#  ('chidda', 40),
#  ('vandweller', 40),
#  ('ksaols', 40),
#  ('henpeckedhal', 40),
#  ('firsttates', 40),
#  ('lumch', 40),
#  ('shitcoin', 40),
#  ('alcoholicly', 40),
#  ('pizzagate', 40),
#  ('mafuta', 40),
#  ('byedon', 40),
#  ('whicons', 40),
#  ('tesarion', 40),
#  ('shimson', 40),
#  ('rozika', 40),
#  ('golloday', 40),
#  ('metteangerhofer', 40),
#  ('notifyclean', 40),
#  ('candycon', 40),
#  ('sobernaughts', 40),
#  ('vessup', 40),
#  ('jlaut', 40),
#  ('marlebean', 40),
#  ('schrdinger', 40),
#  ('rotalla', 40),
#  ('iguaskas', 40),
#  ('overhated', 40),
#  ('nearley', 40),
#  ('bearmarket', 40),
#  ('tasmiling', 40),
#  ('tankmilla', 40),
#  ('retwisted', 40),
#  ('sanatanis', 40),
#  ('kabilla', 40),
#  ('watesubreddit', 40),
#  ('moosoppart', 40),
#  ('bampfa', 40),
#  ('emojippix', 40),
#  ('aponea', 40),
#  ('jmods', 40),
#  ('perfectsweeties', 40),
#  ('lincnotfound', 40),
#  ('swartists', 40),
#  ('zerath', 40),
#  ('elenoa', 40),
#  ('wallipop', 40),
#  ('richarlison', 40),
#  ('misinformers', 40),
#  ('duckpaints', 40),
#  ('swissborg', 40),
#  ('gamanon', 40),
#  ('neurodivergent', 40),
#  ('auaffiliates', 40),
#  ('umberak', 40),
#  ('thenyamproject', 40),
#  ('ootl', 40),
#  ('floridada', 40),
#  ('vengencemedia', 40),
#  ('dompens', 40),
#  ('islisp', 40),
#  ('ellingen', 40),
#  ('mbel', 40),
#  ('serpclix', 40),
#  ('deorr', 40),
#  ('stockx', 40),
#  ('clickbait', 40),
#  ('kuzembo', 40),
#  ('acartooncat', 40),
#  ('bupernorphine', 40),
#  ('farmapram', 40),
#  ('lootboxes', 40),
#  ('usyk', 40),
#  ('menustral', 40),
#  ('menustration', 40),
#  ('insurancebranch', 40),
#  ('garahan', 40),
#  ('vbucks', 40),
#  ('dedenne', 40),
#  ('civmike', 40),
#  ('zeratu', 40),
#  ('jeegujje', 40),
#  ('multipulls', 40),
#  ('garboski', 40),
#  ('chunkerberry', 40),
#  ('vaxx', 40),
#  ('zacian', 40),
#  ('circumstanceseven', 40),
#  ('widet', 40),
#  ('thesiss', 40),
#  ('browtweaten', 40),
#  ('lostfelicia', 40),
#  ('zamasu', 40),
#  ('reposters', 40),
#  ('dragalge', 40),
#  ('glycophosphate', 40),
#  ('kurucs', 40),
#  ('zylinders', 40),
#  ('ramitelli', 40),
#  ('tradingbots', 40),
#  ('allanforsyth', 40),
#  ('divergentmama', 40),
#  ('updoots', 40),
#  ('owlf', 40),
#  ('andyjokedagain', 40),
#  ('croads', 40),
#  ('antivaxxer', 40),
#  ('emojia', 40),
#  ('galarian', 40),
#  ('zamazenta', 40),
#  ('daveastated', 40),
#  ('amadeuschavez', 40),
#  ('blackors', 40),
#  ('pumre', 40),
#  ('neuon', 40),
#  ('sofarrsogud', 40),
#  ('ebabil', 40),
#  ('heqet', 40),
#  ('emojic', 40),
#  ('combkesmiling', 40),
#  ('entexchange', 40),
#  ('mattrum', 40),
#  ('printful', 40),
#  ('cocksucka', 40),
#  ('outletpc', 40),
#  ('axienty', 40),
#  ('mymonero', 40),
#  ('beesubreddit', 40),
#  ('csnaber', 40),
#  ('corsier', 40),
#  ('landwehrmann', 40),
#  ('ethorse', 40),
#  ('psbattle', 40),
#  ('leetcode', 40),
#  ('arrokuda', 40),
#  ('plaudo', 40),
#  ('mhet', 40),
#  ('thancred', 40),
#  ('autonotification', 40),
#  ('regerts', 40),
#  ('mutos', 40),
#  ('coneorphism', 40),
#  ('kanubhai', 40),
#  ('idran', 40),
#  ('domrmy', 40),
#  ('nkla', 40),
#  ('volquardsen', 40),
#  ('irositive', 40),
#  ('arthmoor', 40),
#  ('levedopa', 40),
#  ('xnotifications', 40),
#  ('whatbabytalk', 39),
#  ('trezor', 38),
#  ('boughshough', 38),
#  ('shadowbanned', 36),
#  ('mccaff', 36),
#  ('shitcoins', 33),
#  ('untradeables', 31),
#  ('tlsmiling', 31),
#  ('emojir', 31),
#  ('scrachless', 31),
#  ('offertoro', 30),
#  ('browsesubreddit', 30),
#  ('boorus', 30),
#  ('localbitcoins', 30),
#  ('roastme', 30),
#  ('boogars', 30),
#  ('swiftline', 30),
#  ('sequator', 30),
#  ('osbuddy', 30),
#  ('feasubreddit', 30),
#  ('spoopy', 30),
#  ('frenchbut', 30),
#  ('communiqus', 30),
#  ('berlinwhich', 30),
#  ('spywhich', 30),
#  ('lawyerwho', 30),
#  ('hariwho', 30),
#  ('resumebungled', 30),
#  ('bagooska', 30),
#  ('zeroboros', 30),
#  ('accesscode', 30),
#  ('cardmarket', 30),
#  ('katrinci', 30),
#  ('carfent', 30),
#  ('ebfaadf', 30),
#  ('scorbunny', 30),
#  ('nawalny', 30),
#  ('instaid', 30),
#  ('klonis', 30),
#  ('ttgx', 30),
#  ('compigne', 30),
#  ('pogchamp', 30),
#  ('amanza', 30),
#  ('beatsaber', 30),
#  ('rimuru', 30),
#  ('fangwolves', 30),
#  ('unawaringly', 30),
#  ('dasoku', 30),
#  ('rudeus', 30),
#  ('tknt', 30),
#  ('wbtc', 30),
#  ('dispensarywest', 30),
#  ('showgrow', 30),
#  ('revegging', 30),
#  ('tierlist', 30),
#  ('huion', 30),
#  ('yanl', 30),
#  ('kimtopher', 30),
#  ('shortsleevesuit', 30),
#  ('theboydp', 30),
#  ('chhapiness', 30),
#  ('aimbotters', 30),
#  ('haystory', 30),
#  ('mimeworld', 30),
#  ('vinylcast', 30),
#  ('crosstreks', 30),
#  ('brandpost', 30),
#  ('miricals', 30),
#  ('htbt', 30),
#  ('siliyorum', 30),
#  ('maalesef', 30),
#  ('hodlers', 30),
#  ('bartandsoul', 30),
#  ('lmegordon', 30),
#  ('belladeon', 30),
#  ('lwiay', 30),
#  ('futureme', 30),
#  ('mirrical', 30),
#  ('uptrent', 30),
#  ('purcival', 30),
#  ('mooseallain', 30),
#  ('vicsim', 30),
#  ('vandwell', 30),
#  ('thissmiling', 30),
#  ('handpays', 30),
#  ('aorus', 30),
#  ('minmusic', 30),
#  ('divock', 30),
#  ('delacium', 30),
#  ('redditte', 30),
#  ('pranipat', 30),
#  ('squadleader', 30),
#  ('emojiusk', 30),
#  ('amandarnh', 30),
#  ('portmanteauface', 30),
#  ('avgd', 30),
#  ('zopi', 30),
#  ('yaptm', 30),
#  ('writesubreddit', 30),
#  ('polycryo', 30),
#  ('soulsbourne', 30),
#  ('kinemaster', 30),
#  ('lagmaron', 30),
#  ('neostone', 30),
#  ('ramagos', 30),
#  ('debuffers', 30),
#  ('carvana', 30),
#  ('necrodancer', 30),
#  ('belrain', 30),
#  ('bravethesky', 30),
#  ('niine', 30),
#  ('goofballbirkla', 30),
#  ('iamjackboot', 30),
#  ('thespookykiwi', 30),
#  ('transmogged', 30),
#  ('authosubreddit', 30),
#  ('bekini', 30),
#  ('deplatforming', 30),
#  ('fenneko', 30),
#  ('dryshake', 30),
#  ('xvg', 30),
#  ('thedadvocate', 30),
#  ('loganlowbrow', 30),
#  ('rautha', 30),
#  ('thenanny', 30),
#  ('unsmokeable', 30),
#  ('apothecarium', 30),
#  ('sanatani', 30),
#  ('johnlyontweets', 30),
#  ('lisabug', 30),
#  ('toliss', 30),
#  ('filecoin', 30),
#  ('ferun', 30),
#  ('wolyung', 30),
#  ('thebae', 30),
#  ('adgem', 30),
#  ('covids', 30),
#  ('webewal', 30),
#  ('pavarottri', 30),
#  ('mundakk', 30),
#  ('hogona', 30),
#  ('qiskit', 30),
#  ('schmuk', 30),
#  ('teachesubreddit', 30),
#  ('desaily', 30),
#  ('simorghs', 30),
#  ('halqifibrax', 30),
#  ('bihamut', 30),
#  ('snkrs', 30),
#  ('remismiling', 30),
#  ('granttanaka', 30),
#  ('blursed', 30),
#  ('umtiti', 30),
#  ('pregabablin', 30),
#  ('flualp', 30),
#  ('ronnui', 30),
#  ('bigjdubz', 30),
#  ('superspreader', 30),
#  ('notmythirdrodeo', 30),
#  ('floppyaction', 30),
#  ('sunzzz', 30),
#  ('jervaise', 30),
#  ('tusciano', 30),
#  ('ryzens', 30),
#  ('voidpunk', 30),
#  ('ebarbs', 30),
#  ('wayv', 30),
#  ('raoq', 30),
#  ('hakknda', 30),
#  ('alzolay', 30),
#  ('loritha', 30),
#  ('basubreddit', 30),
#  ('osmiling', 30),
#  ('eredas', 30),
#  ('vstergtland', 30),
#  ('stergtland', 30),
#  ('brdrafolkens', 30),
#  ('broderfolkenes', 30),
#  ('lineageos', 30),
#  ('jornery', 30),
#  ('sympthom', 30),
#  ('rhaegal', 30),
#  ('gobblegums', 30),
#  ('keepkey', 30),
#  ('bissaka', 30),
#  ('noobtonic', 30),
#  ('boruto', 30),
#  ('cdramas', 30),
#  ('carmanthegirl', 30),
#  ('therealpalmal', 30),
#  ('sweetmomissa', 30),
#  ('simping', 30),
#  ('gsuite', 30),
#  ('gahaz', 30),
#  ('merindan', 30),
#  ('rueage', 30),
#  ('audibooks', 30),
#  ('bloodthirstylord', 30),
#  ('pubgm', 30),
#  ('cinderace', 30),
#  ('lovenlunchmeat', 30),
#  ('baymax', 30),
#  ('bramhasmi', 30),
#  ('omisego', 30),
#  ('pspspspspsps', 30),
#  ('mortytania', 30),
#  ('masmiling', 30),
#  ('moonblast', 30),
#  ('copperajah', 30),
#  ('swholic', 30),
#  ('gync', 30),
#  ('psmiling', 30),
#  ('nasem', 30),
#  ('oumuamua', 30),
#  ('konosuba', 30),
#  ('youshop', 30),
#  ('sandwichghoul', 30),
#  ('blucci', 30),
#  ('thankssmiling', 30),
#  ('byleth', 30),
#  ('zeraora', 30),
#  ('undermap', 30),
#  ('infodemic', 30),
#  ('clonazolam', 30),
#  ('yeetus', 30),
#  ('botandy', 30),
#  ('tarkov', 30),
#  ('sylvando', 30),
#  ('teargassing', 30),
#  ('stonjourner', 30),
#  ('adpz', 30),
#  ('capnwatsisname', 30),
#  ('beersie', 30),
#  ('willowdell', 30),
#  ('edingtons', 30),
#  ('watanya', 30),
#  ('cicilla', 30),
#  ('spanishamerican', 30),
#  ('engineportal', 30),
#  ('paraoud', 30),
#  ('distrokid', 30),
#  ('aduser', 30),
#  ('objmanager', 30),
#  ('insivia', 30),
#  ('boogtweets', 30),
#  ('cafeinatedbacon', 30),
#  ('cybermancubi', 30),
#  ('rollergator', 30),
#  ('chungus', 30),
#  ('jarrarium', 30),
#  ('dracovish', 30),
#  ('mcnuggetgang', 30),
#  ('anthoston', 30),
#  ('luminic', 30),
#  ('cooltime', 30),
#  ('shootydoody', 30),
#  ('ultraboosts', 30),
#  ('undesiccated', 30),
#  ('silvesubreddit', 30),
#  ('taclooc', 30),
#  ('cisgenics', 30),
#  ('eithercryingor', 30),
#  ('unstake', 30),
#  ('tsesarevich', 30),
#  ('williamader', 30),
#  ('memeing', 30),
#  ('xiaoyou', 30),
#  ('letsgiveitaspin', 30),
#  ('buluc', 30),
#  ('kryzazy', 30),
#  ('swago', 30),
#  ('youcammakeup', 30),
#  ('segouin', 30),
#  ('tireurs', 30),
#  ('huobi', 30),
#  ('exculded', 30),
#  ('yoshikage', 30),
#  ('defunctioning', 30),
#  ('emojinegative', 30),
#  ('quarantimes', 30),
#  ('tennogen', 30),
#  ('bitoasis', 30),
#  ('sushants', 30),
#  ('rigghhht', 30),
#  ('hiberfil', 30),
#  ('mainnet', 30),
#  ('hillstreams', 30),
#  ('huol', 30),
#  ('xppen', 30),
#  ('blackchip', 30),
#  ('outrune', 30),
#  ('contactsupport', 30),
#  ('maybepilejokes', 30),
#  ('djarin', 30),
#  ('mehmedbai', 30),
#  ('lojka', 30),
#  ('lpplppr', 30),
#  ('kccr', 30),
#  ('naykid', 30),
#  ('kabubky', 30),
#  ('rescourses', 30),
#  ('winrewards', 30),
#  ('nzpost', 30),
#  ('stauffenbeg', 30),
#  ('dorsophilae', 30),
#  ('coppositive', 30),
#  ('coppegative', 30),
#  ('accessilibity', 30),
#  ('ivern', 30),
#  ('harroo', 30),
#  ('hirris', 30),
#  ('otometal', 30),
#  ('runoldman', 28),
#  ('cuaio', 27),
#  ('valcyn', 26),
#  ('menaphos', 26),
#  ('madlad', 25),
#  ('taxfreesnus', 25),
#  ('hashplants', 24),
#  ('gretchenvb', 24),
#  ('heatbed', 24),
#  ('badacey', 23),
#  ('nutsaremixed', 23),
#  ('aisubreddit', 22),
#  ('sabrefan', 22),
#  ('gudetama', 21),
#  ('rngesus', 21),
#  ('sportsbets', 21),
#  ('interfeard', 21),
#  ('marylents', 20),
#  ('tdumped', 20),
#  ('deadname', 20),
#  ('bhraatas', 20),
#  ('pataal', 20),
#  ('doffy', 20),
#  ('beeeeen', 20),
#  ('antosha', 20),
#  ('cutgut', 20),
#  ('emojiqw', 20),
#  ('wgxcq', 20),
#  ('starpowers', 20),
#  ('suboclade', 20),
#  ('reeeeeeeeeeee', 20),
#  ('mmtcs', 20),
#  ('emiratesssssss', 20),
#  ('andreigameover', 20),
#  ('lushens', 20),
#  ('karambits', 20),
#  ('smort', 20),
#  ('ondancetran', 20),
#  ('gamedebate', 20),
#  ('linusmiling', 20),
#  ('ainz', 20),
#  ('watchos', 20),
#  ('bithumb', 20),
#  ('bakchods', 20),
#  ('airduster', 20),
#  ('apollousa', 20),
#  ('ocimene', 20),
#  ('necrozma', 20),
#  ('rowleggs', 20),
#  ('newsguard', 20),
#  ('loadednz', 20),
#  ('chromecasts', 20),
#  ('blundergat', 20),
#  ('redicolous', 20),
#  ('pudgypidge', 20),
#  ('tachanka', 20),
#  ('gokuser', 20),
#  ('princehydra', 20),
#  ('coalassal', 20),
#  ('marshadow', 20),
#  ('trevnoir', 20),
#  ('fauquissart', 20),
#  ('priers', 20),
#  ('honkerlands', 20),
#  ('amfetamine', 20),
#  ('xhv', 20),
#  ('natewantstobattle', 20),
#  ('thegamblersfallacy', 20),
#  ('bedonkohe', 20),
#  ('whna', 20),
#  ('caiross', 20),
#  ('yoosung', 20),
#  ('boxming', 20),
#  ('sunnydecree', 20),
#  ('noonlight', 20),
#  ('bobbyeth', 20),
#  ('noweth', 20),
#  ('predatorhuntinggrounds', 20),
#  ('candyflipping', 20),
#  ('thecrucible', 20),
#  ('storj', 20),
#  ('thedispensary', 20),
#  ('munchery', 20),
#  ('dammmmmn', 20),
#  ('eqts', 20),
#  ('skarmy', 20),
#  ('rebrafsim', 20),
#  ('timothygriff', 20),
#  ('frybo', 20),
#  ('dbxp', 20),
#  ('antiheal', 20),
#  ('iftt', 20),
#  ('silerim', 20),
#  ('yazmm', 20),
#  ('bayadr', 20),
#  ('lurkathomemom', 20),
#  ('ramblinma', 20),
#  ('jjsummertime', 20),
#  ('jabeur', 20),
#  ('ctrol', 20),
#  ('bzrx', 20),
#  ('spyfall', 20),
#  ('wetmascara', 20),
#  ('andrewsnotfunny', 20),
#  ('drakegatsby', 20),
#  ('justmeturtle', 20),
#  ('adharmic', 20),
#  ('burchestgaden', 20),
#  ('wolfsschanze', 20),
#  ('emberfund', 20),
#  ('overspecialized', 20),
#  ('vallys', 20),
#  ('logpile', 20),
#  ('mcnarstle', 20),
#  ('mnateshyamalan', 20),
#  ('emojid', 20),
#  ('horrosubreddit', 20),
#  ('roowards', 20),
#  ('multyplyers', 20),
#  ('setkick', 20),
#  ('pasives', 20),
#  ('pemyslid', 20),
#  ('manavs', 20),
#  ('rwcc', 20),
#  ('ligma', 20),
#  ('aslnda', 20),
#  ('kaybettik', 20),
#  ('ooooof', 20),
#  ('festivvs', 20),
#  ('thingst', 20),
#  ('oregairu', 20),
#  ('blcher', 20),
#  ('saroanco', 20),
#  ('reapp', 20),
#  ('reveg', 20),
#  ('primekwgt', 20),
#  ('packwidgets', 20),
#  ('emojietail', 20),
#  ('vrdgar', 20),
#  ('bioavail', 20),
#  ('fqj', 20),
#  ...]

# %%
if 'GLOVE' in EMBEDDINGS:
    embeddings.add_vector('<pad>',np.zeros((embeddings.vector_size)))
    embeddings.add_vector('<unk>',np.mean(embeddings.vectors,axis=0, keepdims=True)[0])
elif EMBEDDINGS=='FASTTEXT':
    pass
# Out:
# c:\Users\rodri\AppData\Local\Programs\Python\Python39\lib\site-packages\gensim\models\keyedvectors.py:552: UserWarning: Adding single vectors to a KeyedVectors which grows by one each time can be costly. Consider adding in batches or preallocating to the required size.
#   warnings.warn(

# %%
if 'GLOVE' in EMBEDDINGS:
    
    train_df['Tokens'] = train_df['Text'].apply(lambda s:[embeddings.key_to_index.get(tok,embeddings.key_to_index['<unk>']) for tok in re.findall(r"\w+|[^\w\s]", s, re.UNICODE)])

# %%
import numpy as np
def vectorize_post(post, embeddings,method='mean'):
    #Create document vectors by averaging word vectors. Remove out-of-vocabulary words.
    
    vecs = []
    for token in post:
       
        vecs+=[embeddings[token]]
        
        
    if method=='mean':
        return np.mean(vecs, axis=0)
    elif method=='max':
        return np.max(vecs, axis=0)
    elif method=='min':
        return np.min(vecs, axis=0)

# %%
import re

if 'GLOVE' in EMBEDDINGS:
    train_df['Vector'] = train_df['Tokens'].apply(lambda post:vectorize_post(post,embeddings,METHOD))
    #test_df['Vector'] = test_df['Tokens'].apply(lambda post:vectorize_post(post,embeddings,METHOD))

elif 'FASTTEXT' in EMBEDDINGS:
    train_df['Vector'] = train_df['Text'].apply(lambda post:vectorize_post(re.findall(r"\w+|[^\w\s]", post, re.UNICODE),embeddings,METHOD))
    #test_df['Vector'] = test_df['Text'].apply(lambda post:vectorize_post(post.split(" "),embeddings,METHOD))
# Out:
# "\nX_train = pd.DataFrame(train_df['Vector'].values.tolist(), index = train_df.index)\ny_train = train_df['Label']\nX_test = pd.DataFrame(test_df['Vector'].values.tolist(), index = test_df.index)\n\n#X_test = test_df[['User','Window_id','Vector']]\ny_test = test_df['Label']\nX_train\n"

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
#from sklearn.preprocessing import MinMaxScaler


def custom_cv(model, df, n_folds=5,sent =False ,threshold=None):
    skf = StratifiedKFold(n_splits=n_folds)
    user_label_df =df.drop_duplicates('User')
    users = user_label_df['User'].to_numpy()
    
    labels = user_label_df['Label'].to_numpy()
    #print(labels)
    #print(users.shape,labels.shape)
    
    f1_scores = []
    for train_index, test_index in skf.split(users, labels):
        train_users = [users[f] for f in train_index]
        test_users = [users[f] for f in test_index]

        train_folds = df[df['User'].isin(train_users)].copy()
        test_folds = df[df['User'].isin(test_users)].copy()
        #train_folds['Tokens'] = train_folds['Text'].apply(lambda s:[glove_embeddings.key_to_index.get(tok,glove_embeddings.key_to_index['<unk>']) for tok in s.split(" ")])
        #test_folds['Tokens'] = test_folds['Text'].apply(lambda s:[glove_embeddings.key_to_index.get(tok,glove_embeddings.key_to_index['<unk>']) for tok in s.split(" ")])
        #train_folds['Vector'] = train_folds['Tokens'].apply(lambda post:vectorize_post(post,glove_embeddings,METHOD))
        #test_folds['Vector'] = test_folds['Tokens'].apply(lambda post:vectorize_post(post,glove_embeddings,METHOD))
        X_train = pd.DataFrame(train_folds['Vector'].values.tolist(), index = train_folds.index)
        y_train = train_folds['Label']
        X_test = pd.DataFrame(test_folds['Vector'].values.tolist(), index = test_folds.index)
        y_test = test_folds['Label']
        if sent:
            #scaler = MinMaxScaler()
            #train_folds[['polarity','subjectivity','negativity','positivity','neutrality','compound']] = scaler.fit_transform(train_folds[['polarity','subjectivity','negativity','positivity','neutrality','compound']])
            #test_folds[['polarity','subjectivity','negativity','positivity','neutrality','compound']] = scaler.transform(test_folds[['polarity','subjectivity','negativity','positivity','neutrality','compound']])
            X_train = np.c_[X_train,train_folds['polarity'],train_folds['subjectivity'],train_folds['negativity'],train_folds['positivity'],train_folds['neutrality'], train_folds['compound']] 
            X_test = np.c_[X_test,test_folds['polarity'],test_folds['subjectivity'],test_folds['negativity'],test_folds['positivity'],test_folds['neutrality'], test_folds['compound']] 
            

        
        
        model.fit(X_train, y_train)
        f1_scores.append(f1_score(y_test,model.predict(X_test)))

    return f1_scores

# %%
#X_train = X_train.apply(lambda x: vectorize_post(x, glove_embeddings))
#X_train
#train_df

# %%
#X_train[0].shape
#if sentiment:
#    X_train = np.c_[X_train,train_df['polarity'],train_df['subjectivity'],train_df['negativity'],train_df['positivity'],train_df['neutrality'], train_df['compound']] 
#    X_test = np.c_[X_test,test_df['polarity'],test_df['subjectivity'],test_df['negativity'],test_df['positivity'],test_df['neutrality'], test_df['compound']]

# %%
train_df['Vector']
# Out:
# 0         [-0.0067410273, 0.022994056, -0.06323666, -0.1...
# 1         [-0.062390674, 0.05457047, 0.026383927, -0.110...
# 2         [-0.035383556, 0.027473597, -0.036821682, -0.1...
# 3         [-0.035688918, 0.056273665, -0.033792444, -0.1...
# 4         [-0.017818723, 0.03752326, -0.10130639, -0.101...
#                                 ...
# 120176    [-0.008870341, 0.035673823, -0.041841637, -0.1...
# 120177    [-0.025309974, 0.04168036, -0.052140344, -0.10...
# 120178    [-0.050140724, 0.02908735, -0.025017094, -0.17...
# 120179    [-0.0031832538, 0.02555157, -0.041190375, -0.1...
# 120180    [-0.01036954, 0.00635363, -0.048583932, -0.117...
# Name: Vector, Length: 120181, dtype: object

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import MultinomialNB
if BASELINE_COMP:
        models = {
                'sgdLR':SGDClassifier(random_state=seed,loss='log'),
                'sgdlSVM':SGDClassifier(random_state=seed,loss='hinge'),
                'ExtraTrees':ExtraTreesClassifier(random_state=seed,n_jobs=-1),\
                'Perceptron':Perceptron(random_state=seed)}
        report=""
        best_model_name = ""
        best_model=None
        best_f1=0
        for model_name, model in models.items():
                res = custom_cv(model,train_df)
                if np.mean(res) > best_f1:
                        best_f1=np.mean(res)
                        best_model_name=model_name
                        best_model=model
                report+=f"{model_name} f1: {round(np.mean(res),3)}\n"
                print(f"{model_name} f1: {round(np.mean(res),3)}")
        with open(f"{MODEL_PATH}/baseline_report_{EMBEDDINGS}.txt",'w') as f:
                f.write(report)

# %%
#if BASELINE_COMP:
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()
train_df['TB'] = train_df['Text'].apply(lambda text: TextBlob(text).sentiment)
train_df['VADER'] = train_df['Text'].apply(lambda text: sia.polarity_scores(text))


train_df['polarity'] = train_df['TB'].apply(lambda tb: (tb[0]+1/2))
train_df['subjectivity'] = train_df['TB'].apply(lambda tb: tb[1])
train_df['negativity'] = train_df['VADER'].apply(lambda v: v['neg'])
train_df['positivity'] = train_df['VADER'].apply(lambda v: v['pos'])
train_df['neutrality'] = train_df['VADER'].apply(lambda v: v['neu'])
train_df['compound'] = train_df['VADER'].apply(lambda v: (v['compound']+1)/2)



train_df.drop(['VADER','TB'], inplace=True, axis=1)

# %%
if BASELINE_COMP:
        res = custom_cv(best_model,train_df, sent=True)
        print(f"{best_model_name} f1: {round(np.mean(res),3)}")
        #cv
        with open(f"{MODEL_PATH}/baseline_report_{EMBEDDINGS}.txt",'a') as f:
                f.write(f"\nBest model with sent:\n{best_model_name} f1: {round(np.mean(res),3)}")

# %% [markdown]
# # Hyperparameter tuning

# %% [markdown]
# #### Best performing model was sgd Logistic Regression for window size 10, GLOVE_CC with SA features, having achieved a 0.818 F1 score

# %%
from tqdm import tqdm
import optuna
import joblib

def train_eval_tuning(trial,params, df, sent=False):

    skf = StratifiedKFold(n_splits=5)
    user_label_df =df.drop_duplicates('User')
    users = user_label_df['User'].to_numpy()
    
    labels = user_label_df['Label'].to_numpy()

    
    f1_scores = []
    for fold,(train_index, test_index) in enumerate(skf.split(users, labels)):
        train_users = [users[f] for f in train_index]
        test_users = [users[f] for f in test_index]

        train_folds = df[df['User'].isin(train_users)]
        X_train = pd.DataFrame(train_folds['Vector'].values.tolist(), index = train_folds.index)

        test_folds = df[df['User'].isin(test_users)]
        X_test = pd.DataFrame(test_folds['Vector'].values.tolist(), index = test_folds.index)

        model = SGDClassifier(**params)
        if sent:
            X_train = np.c_[X_train,train_folds['polarity'],train_folds['subjectivity'],train_folds['negativity'],train_folds['positivity'],train_folds['neutrality'], train_folds['compound']] 
            X_test = np.c_[X_test,test_folds['polarity'],test_folds['subjectivity'],test_folds['negativity'],test_folds['positivity'],test_folds['neutrality'], test_folds['compound']] 
            

        model.fit(X_train, train_folds['Label'])
        f1_scores.append(f1_score(test_folds['Label'],model.predict(X_test)))
    
        trial.report(np.mean(f1_scores), fold)

        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return f1_scores

# %%
def tuning_objective(trial):
    parameters = {
        'max_iter':trial.suggest_int('max_iter',1000,2500,step=500),
        'loss':trial.suggest_categorical('loss',['log']),
        'penalty':trial.suggest_categorical('penalty',['l2','l1','elasticnet']),
        'alpha': trial.suggest_float('alpha',0.00001,0.1,log=True),
        'random_state':trial.suggest_int('random_state',seed,seed)
        
        
    }
    
  
    
    avg_f1 = train_eval_tuning(trial,parameters,train_df, sent=True)
    return np.mean(avg_f1)

# %%
study = optuna.create_study(
        study_name=f"t{TASK}_tuning_{ROLLING_WINDOW_SIZE}",
        direction='maximize')
study.optimize(tuning_objective, n_trials=50, timeout=(60*60*3))
joblib.dump(study,f"t{TASK}_tuning_{ROLLING_WINDOW_SIZE}.pkl")
    #study = optuna.create_study(study_name=f"tfidfvectorizer_cv_{ROLLING_WINDOW_SIZE}",direction="maximize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.NopPruner())
study = joblib.load(f"t{TASK}_tuning_{ROLLING_WINDOW_SIZE}.pkl")
# Out:
# [I 2022-06-15 18:06:59,501] A new study created in memory with name: t1_tuning_10
# [I 2022-06-15 18:07:56,284] Trial 0 finished with value: 0.6703370650807627 and parameters: {'max_iter': 1000, 'loss': 'log', 'penalty': 'l1', 'alpha': 0.010493375115403552, 'random_state': 23}. Best is trial 0 with value: 0.6703370650807627.
# [I 2022-06-15 18:08:48,069] Trial 1 finished with value: 0.8028821871916568 and parameters: {'max_iter': 1000, 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.000543173554137824, 'random_state': 23}. Best is trial 1 with value: 0.8028821871916568.
# [I 2022-06-15 18:09:42,532] Trial 2 finished with value: 0.7554254504117268 and parameters: {'max_iter': 2500, 'loss': 'log', 'penalty': 'l1', 'alpha': 0.002478740563155032, 'random_state': 23}. Best is trial 1 with value: 0.8028821871916568.
# [I 2022-06-15 18:10:49,994] Trial 3 finished with value: 0.8010223875891327 and parameters: {'max_iter': 1000, 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 1.0319513599229012e-05, 'random_state': 23}. Best is trial 1 with value: 0.8028821871916568.
# [I 2022-06-15 18:11:43,707] Trial 4 finished with value: 0.7994783498518758 and parameters: {'max_iter': 1500, 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.00018799224889124342, 'random_state': 23}. Best is trial 1 with value: 0.8028821871916568.
# [I 2022-06-15 18:11:54,494] Trial 5 pruned.
# [I 2022-06-15 18:12:04,875] Trial 6 pruned.
# [I 2022-06-15 18:13:08,745] Trial 7 finished with value: 0.8092157464796614 and parameters: {'max_iter': 1000, 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 1.74644393785219e-05, 'random_state': 23}. Best is trial 7 with value: 0.8092157464796614.
# [I 2022-06-15 18:14:02,128] Trial 8 finished with value: 0.8060824619032905 and parameters: {'max_iter': 2500, 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.000256484843475983, 'random_state': 23}. Best is trial 7 with value: 0.8092157464796614.
# [I 2022-06-15 18:14:11,583] Trial 9 pruned.
# [I 2022-06-15 18:15:10,544] Trial 10 finished with value: 0.815767016295737 and parameters: {'max_iter': 1500, 'loss': 'log', 'penalty': 'l2', 'alpha': 1.3686668032740659e-05, 'random_state': 23}. Best is trial 10 with value: 0.815767016295737.
# [I 2022-06-15 18:16:09,529] Trial 11 finished with value: 0.8155169367239319 and parameters: {'max_iter': 1500, 'loss': 'log', 'penalty': 'l2', 'alpha': 1.3338944613625493e-05, 'random_state': 23}. Best is trial 10 with value: 0.815767016295737.
# [I 2022-06-15 18:16:19,879] Trial 12 pruned.
# [I 2022-06-15 18:17:11,862] Trial 13 finished with value: 0.8184723675793573 and parameters: {'max_iter': 1500, 'loss': 'log', 'penalty': 'l2', 'alpha': 5.679575179154025e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:18:03,264] Trial 14 finished with value: 0.8182411829028977 and parameters: {'max_iter': 2000, 'loss': 'log', 'penalty': 'l2', 'alpha': 6.287927130649376e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:18:54,760] Trial 15 finished with value: 0.8178474852319614 and parameters: {'max_iter': 2000, 'loss': 'log', 'penalty': 'l2', 'alpha': 7.673866027292762e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:19:45,890] Trial 16 finished with value: 0.8166092565927763 and parameters: {'max_iter': 2000, 'loss': 'log', 'penalty': 'l2', 'alpha': 8.224205868393281e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:19:55,499] Trial 17 pruned.
# [I 2022-06-15 18:20:47,004] Trial 18 finished with value: 0.8179474532775906 and parameters: {'max_iter': 2000, 'loss': 'log', 'penalty': 'l2', 'alpha': 7.320183954684968e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:20:56,905] Trial 19 pruned.
# [I 2022-06-15 18:21:06,430] Trial 20 pruned.
# [I 2022-06-15 18:21:58,571] Trial 21 pruned.
# [I 2022-06-15 18:22:08,967] Trial 22 pruned.
# [I 2022-06-15 18:23:01,000] Trial 23 finished with value: 0.8167867297356415 and parameters: {'max_iter': 1500, 'loss': 'log', 'penalty': 'l2', 'alpha': 8.441611237395973e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:23:10,720] Trial 24 pruned.
# [I 2022-06-15 18:23:23,852] Trial 25 pruned.
# [I 2022-06-15 18:23:34,237] Trial 26 pruned.
# [I 2022-06-15 18:23:43,902] Trial 27 pruned.
# [I 2022-06-15 18:24:35,378] Trial 28 finished with value: 0.8184272938554493 and parameters: {'max_iter': 2500, 'loss': 'log', 'penalty': 'l2', 'alpha': 6.319539398481264e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:24:53,864] Trial 29 pruned.
# [I 2022-06-15 18:25:03,323] Trial 30 pruned.
# [I 2022-06-15 18:25:55,424] Trial 31 pruned.
# [I 2022-06-15 18:26:46,584] Trial 32 finished with value: 0.8163987439649221 and parameters: {'max_iter': 2000, 'loss': 'log', 'penalty': 'l2', 'alpha': 0.00010766383458860656, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:27:38,842] Trial 33 pruned.
# [I 2022-06-15 18:27:49,521] Trial 34 pruned.
# [I 2022-06-15 18:27:59,430] Trial 35 pruned.
# [I 2022-06-15 18:28:08,999] Trial 36 pruned.
# [I 2022-06-15 18:28:19,199] Trial 37 pruned.
# [I 2022-06-15 18:28:30,685] Trial 38 pruned.
# [I 2022-06-15 18:28:40,989] Trial 39 pruned.
# [I 2022-06-15 18:28:50,913] Trial 40 pruned.
# [I 2022-06-15 18:29:42,429] Trial 41 finished with value: 0.8180770412820504 and parameters: {'max_iter': 2000, 'loss': 'log', 'penalty': 'l2', 'alpha': 7.3967263996645e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:30:33,968] Trial 42 finished with value: 0.8184504407475153 and parameters: {'max_iter': 2000, 'loss': 'log', 'penalty': 'l2', 'alpha': 6.325158989294057e-05, 'random_state': 23}. Best is trial 13 with value: 0.8184723675793573.
# [I 2022-06-15 18:31:27,214] Trial 43 pruned.
# [I 2022-06-15 18:31:37,167] Trial 44 pruned.
# [I 2022-06-15 18:31:48,502] Trial 45 pruned.
# [I 2022-06-15 18:31:58,855] Trial 46 pruned.
# [I 2022-06-15 18:32:08,747] Trial 47 pruned.
# [I 2022-06-15 18:33:00,829] Trial 48 finished with value: 0.8186599122555993 and parameters: {'max_iter': 2000, 'loss': 'log', 'penalty': 'l2', 'alpha': 5.6567497467221377e-05, 'random_state': 23}. Best is trial 48 with value: 0.8186599122555993.
# [I 2022-06-15 18:33:11,796] Trial 49 pruned.

# %%
study.best_trial.params, study.best_value
# Out:
# ({'max_iter': 2000,
#   'loss': 'log',
#   'penalty': 'l2',
#   'alpha': 5.6567497467221377e-05,
#   'random_state': 23},
#  0.8186599122555993)

# %%
with open(f"{MODEL_PATH}/baseline_report_{EMBEDDINGS}.txt",'a') as f:
                f.write(f"\nOptimized model f1: {round(study.best_value,3)}\nparams: {study.best_trial.params}")

# %%
sgdLR_params = study.best_trial.params

final_model = SGDClassifier(**sgdLR_params)
X_train = pd.DataFrame(train_df['Vector'].values.tolist(), index = train_df.index)

X_train = np.c_[X_train,train_df['polarity'],train_df['subjectivity'],train_df['negativity'],train_df['positivity'],train_df['neutrality'], train_df['compound']] 


final_model.fit(X_train, train_df['Label'])
save_model(final_model, "optimized_sgdLR.pkl")
